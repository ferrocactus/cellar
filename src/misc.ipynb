# %%
from src.workflow import Workflow
from src.utils_experiment import read_config
from src.utils_data import load_data
from matplotlib import pyplot as plt
import numpy as np

from src.utils_visualization import reduce_and_plot

import warnings
warnings.filterwarnings('ignore')

# %%
config = read_config('spellman')
X, Y = load_data(config['dataset']['name'])

# %%
w = Workflow(X, Y)

# %%
w.pca_plot_var_ratio()

# %%
w.reduce_dim(method='pca', n_components=7)
# Out:
# Reducing dimensionality using PCA.
# Embedding created. Train MSE: 0.0377468373782888
# Train Average Log Likelihood: -5.644785716429

# %%
w.cluster(method='spectral', n_clusters=8, affinity='nearest_neighbor')
# Out:
# Using embeddings constructed with pca
# Clustering using spectral clustering.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-71c7a4d68cc1> in <module>
# ----> 1 w.cluster(method='spectral', n_clusters=8)
#
# ~/CMU/sc-transcriptomics/src/workflow.py in cluster(self, method, **kwargs)
#     152             print("Clustering using spectral clustering.")
#     153             spectral = SpectralClustering(**kwargs)
# --> 154             spectral.fit(self.x_train_emb, affinity='nearest_neighbors')
#     155             self.y_train_pred = spectral.labels_
#     156             print('Clustering complete.')
#
# TypeError: fit() got an unexpected keyword argument 'affinity'

# %%
reduce_and_plot(x=w.x_train, y=w.y_train_pred,
                dims=2,
                method='umap',
                n_neighbors=20,
                min_dist=0,
                metric='euclidean')
