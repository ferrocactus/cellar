# %%
from src.workflow import Workflow
from src.utils_experiment import read_config
from src.utils_data import load_data
from matplotlib import pyplot as plt
import numpy as np

from src.utils_visualization import reduce_and_plot

import warnings
warnings.filterwarnings('ignore')

# %%
config = read_config('spellman')
X, Y = load_data(config['dataset']['name'])

# %%
w = Workflow(X, Y)

# %%
w.pca_plot_var_ratio()

# %%
w.reduce_dim(method='pca', n_components=7)
# Out:
# Reducing dimensionality using PCA.
# Embedding created. Train MSE: 0.037747054528823376
# Train Average Log Likelihood: -5.644813100921193

# %%
w.cluster(method='kmeans', n_clusters=8)
# Out:
# Clustering using k-means.
# Clustering complete. Train Score: -6981.876608878734

# %%
reduce_and_plot(x=w.x_train, y=w.y_train_pred,
                dims=2,
                method='umap',
                n_neighbors=20,
                min_dist=0,
                metric='euclidean')
# Out:
# Reducing dimensionality using UMAP.
