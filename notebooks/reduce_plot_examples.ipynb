# %% [markdown]
# <h2>2D Plotting Examples</h2>

# %%
from matplotlib import pyplot as plt
from src.workflow import Workflow
from utils.utils_experiment import load_data
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = 'spleen'
X, Y = load_data(dataset)
w = Workflow(X, Y, config=dataset)

# %%
w.reduce_dim(method='pca')
# Out:
# Embedding created. Train MSE: 0.5090888

# %% [markdown]
# <h3>2D Plot of the Embeddings using UMAP</h3>

# %%
w.reduce_plot(labels=Y, method='umap')
# Out:
# Reducing dimensionality for visualization using umap.

# %% [markdown]
# <h3>2D Plot of the Embeddings using PCA</h3>

# %%
w.reduce_plot(labels=Y, method='pca')
# Out:
# Reducing dimensionality for visualization using pca.

# %% [markdown]
# <h3>2D Plot of the Embeddings using t-SNE</h3>

# %%
w.reduce_plot(labels=Y, method='tsne')
# Out:
# Reducing dimensionality for visualization using tsne.
